# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from os import sys
import os

# %%
sys.path.append(os.path.abspath(os.path.join('../Scripts')))
#from load_data import LoadData
from preprocess import Preprocess
from plot import Plot

# %%
# Data Reading
train_df = pd.read_csv("../Data/train.csv")
test_df = pd.read_csv("../Data/test.csv")

# %% [markdown]
# # Data Overview on each Dataset

# %%
train_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
test_df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
train_df.shape
# Out:
# (1017209, 9)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %%
train_df.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# ...

# %% [markdown]
# For some of the columns, the mean value is very different from the median (50%) value which means there is an outlier

# %%
train_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
# Only want closing price for each day 
sales = train_df[["Sales", "Store"]]
sales.head()
# Out:
#    Sales  Store
# 0   5263      1
# 1   6064      2
# 2   8314      3
# 3  13995      4
# 4   4822      5

# %%
train_df.sort_index(inplace=True)

# %%
sns.set()
train_df[['Sales', 'Store']].plot(figsize=(30, 7))
plt.ylabel("Sales")
plt.title("Sales for stores", fontsize=16)
plt.legend(fontsize=14);

# %% [markdown]
# Promotion distribution in both training and test sets

# %%
Plot.plot_subplots(train_df['Promo'], test_df['Promo'], 'Train data Promo Distribution', 'Test data Promo Distribution',ytitle="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 Plot.plot_subplots(train_df['Promo'], test_df['Promo'], 'Train data Promo Distribution', 'Test data Promo Distribution',ytitle="")
#
# File D:\Tenx Batch 6\Week3\Sales-Prediction\Scripts\plot.py:262, in Plot.plot_subplots(self, x, y, xtitle, ytitle)
#     260 fig.set_size_inches(25, 8)
#     261 x.hist(ax=axes[0], alpha=0.3, color='red', bins=20)
# --> 262 y.hist(ax=axes[1], alpha=0.3, color='blue', bins=20)
#     263 axes[0].set_title(xtitle, size=20)
#     264 axes[1].set_title(ytitle, size=20)
#
# AttributeError: 'str' object has no attribute 'hist'

# %%
Plot.plot_subplots(train_df['SchoolHoliday'], test_df['SchoolHoliday'], 'Train data SchoolHoliday Distribution', 'Test data SchoolHoliday Distribution',ytitle="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 Plot.plot_subplots(train_df['SchoolHoliday'], test_df['SchoolHoliday'], 'Train data SchoolHoliday Distribution', 'Test data SchoolHoliday Distribution',ytitle="")
#
# File D:\Tenx Batch 6\Week3\Sales-Prediction\Scripts\plot.py:262, in Plot.plot_subplots(self, x, y, xtitle, ytitle)
#     260 fig.set_size_inches(25, 8)
#     261 x.hist(ax=axes[0], alpha=0.3, color='red', bins=20)
# --> 262 y.hist(ax=axes[1], alpha=0.3, color='blue', bins=20)
#     263 axes[0].set_title(xtitle, size=20)
#     264 axes[1].set_title(ytitle, size=20)
#
# AttributeError: 'str' object has no attribute 'hist'

# %%
Plot.plot_hist_muli(train_df,train_df)

# %%
Plot.plot_hist_muli(test_df,test_df)

# %%
# Sales during, before and after StateHoliday
Plot.plot_subplots(train_df['StateHoliday'], test_df['StateHoliday'], 'Train data StateHoliday Distribution', 'Test data StateHoliday Distribution',ytitle="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [52], in <cell line: 2>()
#       1 # Sales during, before and after StateHoliday
# ----> 2 Plot.plot_subplots(train_df['StateHoliday'], test_df['StateHoliday'], 'Train data StateHoliday Distribution', 'Test data StateHoliday Distribution',ytitle="")
#
# File D:\Tenx Batch 6\Week3\Sales-Prediction\Scripts\plot.py:262, in Plot.plot_subplots(self, x, y, xtitle, ytitle)
#     260 fig.set_size_inches(25, 8)
#     261 x.hist(ax=axes[0], alpha=0.3, color='red', bins=20)
# --> 262 y.hist(ax=axes[1], alpha=0.3, color='blue', bins=20)
#     263 axes[0].set_title(xtitle, size=20)
#     264 axes[1].set_title(ytitle, size=20)
#
# AttributeError: 'str' object has no attribute 'hist'

# %%
# Using line chart plot sales during, before and after StateHoliday
sns.lineplot(x='StateHoliday', y='Sales', data=train_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [53], in <cell line: 2>()
#       1 # Using line chart plot sales during, before and after StateHoliday
# ----> 2 sns.lineplot(x='StateHoliday', y='Sales', data=train_df)
#
# File ~\anaconda3\envs\TenxAc\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
# Check & compare sales behavior before, during and after holidays
holiday_df = train_df.groupby(['StateHoliday'])['Sales'].mean().reset_index()
holiday_df.head()
# Out:
#   StateHoliday        Sales
# 0            0  5733.530624
# 1            0  5980.279717
# 2            a   290.735686
# 3            b   214.311510
# 4            c   168.733171
